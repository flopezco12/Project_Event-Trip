# %%
import requests
from pprint import pprint

url = "https://tripadvisor16.p.rapidapi.com/api/v1/rentals/searchLocation"

querystring = {"query":"British Columbia"}

headers = {
	"X-RapidAPI-Key": "530b7b7a07mshf83f1e081bca0c9p150b44jsnc99a69d175db",
	"X-RapidAPI-Host": "tripadvisor16.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

pprint(response.json())
# Out:
# {'data': [{'geoId': 154922,
#            'isGeo': True,
#            'latitude': 54.136696,
#            'localizedAdditionalNames': 'Canada, North America',
#            'localizedName': 'British Columbia',
#            'locationId': 154922,
#            'locationV2': 'Canada, North America',
#            'longitude': -124.63623,
#            'placeType': 'PROVINCE',
#            'thumbnail': {'photoSizeDynamic': {'maxHeight': 585,
#                                               'maxWidth': 2995,
#                                               'urlTemplate': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/15/4d/43/ac/british-columbia.jpg?w={width}&h={height}&s=1'}}}],
#  'message': 'Success',
#  'status': True,
#  'timestamp': 1695947889433}

# %%
#to get the different rentals 

import requests

url = "https://tripadvisor16.p.rapidapi.com/api/v1/rentals/rentalSearch"

querystring = {"geoId":"154922","arrival":"2024-01-01","departure":"2024-01-15","sortOrder":"TRAVELERRATINGHIGH","page":"1","currencyCode":"USD"}

headers = {
	"X-RapidAPI-Key": "530b7b7a07mshf83f1e081bca0c9p150b44jsnc99a69d175db",
	"X-RapidAPI-Host": "tripadvisor16.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)



response2 = response.json()

pprint(response2)
# Out:
# {'data': {'filters': {'amenities': {'list': [{'count': 244,
#                                               'id': 9,
#                                               'text': 'Internet or Wifi'},
#                                              {'count': 223,
#                                               'id': 24,
#                                               'text': 'Parking'},
#                                              {'count': 183,
#                                               'id': 23,
#                                               'text': 'Other outdoor space'},
#                                              {'count': 141,
#                                               'id': 26,
#                                               'text': 'Washer/Dryer'},
#                                              {'count': 135,
#                                               'id': 25,
#                                               'text': 'Grill'},
# ...

# %%
#pprint(response2["data"]["rentals"]["rentals"])

rentals = response2["data"]["rentals"]["rentals"]
rentals
# Out:
# [{'id': 1447398,
#   'rentalId': 'VacationRentalReview-g154946-d1447398-The_Gate_House_Cottage_at_Castle_on_the_Mountain-Vernon_Okanagan_Valley_British_Columb',
#   'name': 'The Gate House Cottage at Castle on the Mountain',
#   'rate': {'total': None,
#    'isInstantBook': False,
#    'minStay': None,
#    'checkoutUrls': [],
#    'details': [{'name': None,
#      'type': 'BASE_RATE',
#      'isOptional': None,
#      'rate': {'amount': 2355.08, 'currency': 'USD'}},
#     {'name': None,
#      'type': 'SUBTOTAL',
#      'isOptional': None,
#      'rate': {'amount': 2622.34, 'currency': 'USD'}}]},
#   'rental': {'name': 'The Gate House Cottage at Castle on the Mountain',
#    'titleInfo': {'title': 'The Gate House Cottage at Castle on the Mountain',
#     'reqLang': 'en',
#     'srcLang': 'en'},
#    'bathCount': 1,
#    'sleepCount': 3,
#    'roomCount': 1,
#    'userReviewCount': 3,
#    'averageRatingNumber': 5,
#    'hasPaymentProtection': False,
#    'isAffiliate': True,
# ...

# %%
#looking at overall dataframe

import pandas as pd

rentals_df = pd.DataFrame(rentals)

rentals_df
# Out:
#           id                                           rentalId  \
# 0    1447398  VacationRentalReview-g154946-d1447398-The_Gate...
# 1    1745558  VacationRentalReview-g154943-d1745558-AWARD_WI...
# 2    2001131  VacationRentalReview-g154942-d2001131-Cedar_Sh...
# 3    2018683  VacationRentalReview-g154939-d2018683-Cassiar_...
# 4    2027496  VacationRentalReview-g154945-d2027496-2_bedroo...
# 5    2042477  VacationRentalReview-g154945-d2042477-Luxury_d...
# 6    2091445  VacationRentalReview-g665835-d2091445-Mini_Res...
# 7    2092885  VacationRentalReview-g2614294-d2092885-Waterfr...
# 8    2197534  VacationRentalReview-g499121-d2197534-Coles_La...
# 9    2197535  VacationRentalReview-g499121-d2197535-Tesla_La...
# 10   2634940  VacationRentalReview-g664811-d2634940-The_Cott...
# 11   3505547  VacationRentalReview-g499146-d3505547-Beachsid...
# 12   3579966  VacationRentalReview-g154945-d3579966-Tranquil...
# 13   3627655  VacationRentalReview-g184843-d3627655-Blitz_Be...
# ...

# %%
    
rentals_df = rentals_df.drop('rate',axis=1)
rentals_df
# Out:
#           id                                           rentalId  \
# 0    1447398  VacationRentalReview-g154946-d1447398-The_Gate...
# 1    1745558  VacationRentalReview-g154943-d1745558-AWARD_WI...
# 2    2001131  VacationRentalReview-g154942-d2001131-Cedar_Sh...
# 3    2018683  VacationRentalReview-g154939-d2018683-Cassiar_...
# 4    2027496  VacationRentalReview-g154945-d2027496-2_bedroo...
# 5    2042477  VacationRentalReview-g154945-d2042477-Luxury_d...
# 6    2091445  VacationRentalReview-g665835-d2091445-Mini_Res...
# 7    2092885  VacationRentalReview-g2614294-d2092885-Waterfr...
# 8    2197534  VacationRentalReview-g499121-d2197534-Coles_La...
# 9    2197535  VacationRentalReview-g499121-d2197535-Tesla_La...
# 10   2634940  VacationRentalReview-g664811-d2634940-The_Cott...
# 11   3505547  VacationRentalReview-g499146-d3505547-Beachsid...
# 12   3579966  VacationRentalReview-g154945-d3579966-Tranquil...
# 13   3627655  VacationRentalReview-g184843-d3627655-Blitz_Be...
# ...

# %%
rentals_df = rentals_df.drop('rentalId',axis=1)
rentals_df
# Out:
#           id                                               name  \
# 0    1447398   The Gate House Cottage at Castle on the Mountain
# 1    1745558  AWARD-WINNING LUXURY HERITAGE RESIDENCE NEAR D...
# 2    2001131  Cedar Shack Cottage with private Hot Tub - Ste...
# 3    2018683   Cassiar Cannery ~ where history and nature meet~
# 4    2027496  2 bedroom suite located between Victoria & Sidney
# 5    2042477   Luxury downtown condo, steps to Inner Harbor!!!
# 6    2091445   Mini Resort mins to beach and downtown Peachland
# 7    2092885  Waterfront suite--kit, balcony--12-acre hobbyfarm
# 8    2197534  Coles Lake Lodge- Fly In-Remote Wilderness Get...
# 9    2197535               Tesla Lake Lodge- Wilderness Getaway
# 10   2634940               The Cottage at Secret Cove Treehouse
# 11   3505547   Beachside Ocean Vista Suite, HotTub, Ocean Views
# 12   3579966     Tranquil Malahat Waterfront Retreat Awaits You
# 13   3627655  Blitz Beach House Oceanfront Retreat, North of...
# ...

# %%
rentals_df.set_index("id")
# Out:
#                                                        name  \
# id
# 1447398    The Gate House Cottage at Castle on the Mountain
# 1745558   AWARD-WINNING LUXURY HERITAGE RESIDENCE NEAR D...
# 2001131   Cedar Shack Cottage with private Hot Tub - Ste...
# 2018683    Cassiar Cannery ~ where history and nature meet~
# 2027496   2 bedroom suite located between Victoria & Sidney
# 2042477    Luxury downtown condo, steps to Inner Harbor!!!
# 2091445    Mini Resort mins to beach and downtown Peachland
# 2092885   Waterfront suite--kit, balcony--12-acre hobbyfarm
# 2197534   Coles Lake Lodge- Fly In-Remote Wilderness Get...
# 2197535                Tesla Lake Lodge- Wilderness Getaway
# 2634940                The Cottage at Secret Cove Treehouse
# 3505547    Beachside Ocean Vista Suite, HotTub, Ocean Views
# 3579966      Tranquil Malahat Waterfront Retreat Awaits You
# 3627655   Blitz Beach House Oceanfront Retreat, North of...
# 4058595   Custom Crafted Log Chalet near Fernie, B.C. (B...
# ...

# %%
rentals_df = rentals_df.drop('rental',axis=1)
rentals_df
# Out:
#           id                                               name
# 0    1447398   The Gate House Cottage at Castle on the Mountain
# 1    1745558  AWARD-WINNING LUXURY HERITAGE RESIDENCE NEAR D...
# 2    2001131  Cedar Shack Cottage with private Hot Tub - Ste...
# 3    2018683   Cassiar Cannery ~ where history and nature meet~
# 4    2027496  2 bedroom suite located between Victoria & Sidney
# 5    2042477   Luxury downtown condo, steps to Inner Harbor!!!
# 6    2091445   Mini Resort mins to beach and downtown Peachland
# 7    2092885  Waterfront suite--kit, balcony--12-acre hobbyfarm
# 8    2197534  Coles Lake Lodge- Fly In-Remote Wilderness Get...
# 9    2197535               Tesla Lake Lodge- Wilderness Getaway
# 10   2634940               The Cottage at Secret Cove Treehouse
# 11   3505547   Beachside Ocean Vista Suite, HotTub, Ocean Views
# 12   3579966     Tranquil Malahat Waterfront Retreat Awaits You
# 13   3627655  Blitz Beach House Oceanfront Retreat, North of...
# ...

# %%
rentals
# Out:
# [{'id': 1447398,
#   'rentalId': 'VacationRentalReview-g154946-d1447398-The_Gate_House_Cottage_at_Castle_on_the_Mountain-Vernon_Okanagan_Valley_British_Columb',
#   'name': 'The Gate House Cottage at Castle on the Mountain',
#   'rate': {'total': None,
#    'isInstantBook': False,
#    'minStay': None,
#    'checkoutUrls': [],
#    'details': [{'name': None,
#      'type': 'BASE_RATE',
#      'isOptional': None,
#      'rate': {'amount': 2355.08, 'currency': 'USD'}},
#     {'name': None,
#      'type': 'SUBTOTAL',
#      'isOptional': None,
#      'rate': {'amount': 2622.34, 'currency': 'USD'}}]},
#   'rental': {'name': 'The Gate House Cottage at Castle on the Mountain',
#    'titleInfo': {'title': 'The Gate House Cottage at Castle on the Mountain',
#     'reqLang': 'en',
#     'srcLang': 'en'},
#    'bathCount': 1,
#    'sleepCount': 3,
#    'roomCount': 1,
#    'userReviewCount': 3,
#    'averageRatingNumber': 5,
#    'hasPaymentProtection': False,
#    'isAffiliate': True,
# ...

# %%
rentals[0]["rental"]["name"]
# Out:
# 'The Gate House Cottage at Castle on the Mountain'

# %%
rentals[0]["rental"]["userReviewCount"]
# Out:
# 3

# %%
rentals[0]["rental"]["averageRatingNumber"]
# Out:
# 5

# %%
rentals[1]["rental"]["geoCoordinates"]
# Out:
# {'lat': 49.23602, 'lng': -122.96054}

# %%
# List of rentals

rentalsid = ["1447398", "1745558", "2001131", "2018683", "2027496", "2042477", "2091445", "2092885", "2197534", "2197535", "2634940","3505547", "3579966","3627655"
"4058595", "4272450", "4362299", "4372077","4707364","4939482","6079225","6424015","6614275","6626960","6993561", "7105203","7823182","8059256","8110317","8387914","8591053","8652986"
"8829942","8841322","8841744","9850945","9993366","10023951","10193286","10316687","10530779","12152368","12193874","12250974","12668788","12824746","12916575","13394874","13773068","13956082"]

# set up lists to hold response info
name = []
reviewcount = []
averageratingnumber = []
lat = []
lng = []

# Loop through the list of cities and perform a request for data on each
for x in range(len(rentalsid)):
    name.append(rentals[x]["rental"]["name"])
    reviewcount.append(rentals [x]["rental"]["userReviewCount"])
    averageratingnumber.append(rentals [x]["rental"]["averageRatingNumber"])
    lat.append(rentals[x]["rental"]["geoCoordinates"]["lat"])
    lng.append(rentals[x]["rental"]["geoCoordinates"]["lng"])


rental_dict = {
    "Name": name,
    "Review Count": reviewcount,
    "Average Rating": averageratingnumber,
    "Latitude": lat,
    "Longitude": lng
}

rental_data.to_csv("Bc_Data_Page _1", index=False)
rental_data = pd.DataFrame(rental_dict)
rental_data
# Out:
#                                                  Name  Review Count  \
# 0    The Gate House Cottage at Castle on the Mountain             3
# 1   AWARD-WINNING LUXURY HERITAGE RESIDENCE NEAR D...            20
# 2   Cedar Shack Cottage with private Hot Tub - Ste...            58
# 3    Cassiar Cannery ~ where history and nature meet~            56
# 4   2 bedroom suite located between Victoria & Sidney            19
# 5    Luxury downtown condo, steps to Inner Harbor!!!             19
# 6    Mini Resort mins to beach and downtown Peachland            22
# 7   Waterfront suite--kit, balcony--12-acre hobbyfarm             7
# 8   Coles Lake Lodge- Fly In-Remote Wilderness Get...             1
# 9                Tesla Lake Lodge- Wilderness Getaway             4
# 10               The Cottage at Secret Cove Treehouse            21
# 11   Beachside Ocean Vista Suite, HotTub, Ocean Views             6
# 12     Tranquil Malahat Waterfront Retreat Awaits You            15
# ...
