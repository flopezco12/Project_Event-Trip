# %%
from pathlib import Path
import pandas as pd
import scipy.stats as stats

# %%
# Create a file path
data1_df = pd.read_csv("Resources/Bc_Data_Page _1")
# Read in the data. 
data1_df
# Out:
#                                                  Name  Review Count  \
# 0    The Gate House Cottage at Castle on the Mountain             3
# 1   AWARD-WINNING LUXURY HERITAGE RESIDENCE NEAR D...            20
# 2   Cedar Shack Cottage with private Hot Tub - Ste...            58
# 3    Cassiar Cannery ~ where history and nature meet~            56
# 4   2 bedroom suite located between Victoria & Sidney            19
# 5    Luxury downtown condo, steps to Inner Harbor!!!             19
# 6    Mini Resort mins to beach and downtown Peachland            22
# 7   Waterfront suite--kit, balcony--12-acre hobbyfarm             7
# 8   Coles Lake Lodge- Fly In-Remote Wilderness Get...             1
# 9                Tesla Lake Lodge- Wilderness Getaway             4
# 10               The Cottage at Secret Cove Treehouse            21
# 11   Beachside Ocean Vista Suite, HotTub, Ocean Views             6
# 12     Tranquil Malahat Waterfront Retreat Awaits You            15
# ...

# %%
# Create a file path
data2_df = pd.read_csv("Resources/Bc_Data_Page _2")
# Read in the data. 
data2_df
# Out:
#                                                  Name  Review Count  \
# 0                                    Log Guest Cabin              2
# 1   PRIMROSE PLACE ~ PRIVATE OASIS in Penticton~ C...             3
# 2   The Orchard House in Downtown Sidney by the Se...             1
# 3         16 Mile Wilderness Family Cabin, Dease Lake             1
# 4       Wonderful 1 Bedroom and Den in Lower Lonsdale             3
# 5                Vantastic Rentals Camper van rentals             1
# 6   Vancouver DownTown 1400sqf Sub-penthouse 270*view             8
# 7                              Vantastic Rentals Ltd.             6
# 8                                       Rent The Tent             2
# 9   Villa Sorana (3 bdrm) - Your Active Vacation E...            27
# 10          Barrel Cabins at Jewel Creek Organic Farm             3
# 11  First Class Family Friendly Location - Close t...             1
# 12  Escape to the mountains & Ocean in this 2bedro...             2
# ...

# %%
# Create a file path
data4_df = pd.read_csv("Resources/Bc_Data_Page _4")
# Read in the data. 
data4_df
# Out:
#                                                  Name  Review Count  \
# 0                               The Black Pearl Suite             0
# 1                         Sea Breeze Ocean Front Home             0
# 2                Steps to beach and walks to Downtown             0
# 3   CM301 - 1 Bed-1Bath, Sleeps upto 4, Partial La...             0
# 4                                 Daes Seaside Dream              0
# 5                  RV for Rent, Rental 29 FT Citation             0
# 6   Private Room/Private Bathroom in Orchard w/Lak...             0
# 7                                           SANTA INN             0
# 8   Luxury 2 bedroom in downtown Vancouver with fr...             0
# 9                      1pvt brm in Yaletown beach ave             0
# 10    Upscale Character Home with Luxurious Amenities             0
# 11                                          Mama Bear             0
# 12  When skiing, hiking or wine tasting, Green Vac...             0
# ...

# %%
# Create a file path
data5_df = pd.read_csv("Resources/Bc_Data_Page _5")
# Read in the data. 
data5_df
# Out:
#                                                  Name  Review Count  \
# 0                    Vintage VW Westfalia Camper Vans             0
# 1                                Cornwall Comfort B&B             0
# 2   Very nice condo w/ pool terrace view in vancouver             0
# 3    Sea-esta Suite with Ocean Views in Brentwood Bay             0
# 4                       1 bedroom 1 bunkhouse cottage             0
# 5                                   3 Bedroom Cottage             0
# 6                              Clayoquot Surf Retreat             0
# 7                                   Gem at the Janion             0
# 8                     Spacious Executive Corner Suite             0
# 9           Spacious New Apartment with Working Space             0
# 10                                  Pacific Rim Cabin             0
# 11        The Mermaid Lounge - 1 Bed Oceanfront Suite             0
# 12                         Dream Home, Dream Location             0
# ...

# %%
full_data_tp_df = pd.concat([data1_df,data2_df,data4_df,data5_df], axis=0, ignore_index=True)
full_data_tp_df
# Out:
#                                                   Name  Review Count  \
# 0     The Gate House Cottage at Castle on the Mountain             3
# 1    AWARD-WINNING LUXURY HERITAGE RESIDENCE NEAR D...            20
# 2    Cedar Shack Cottage with private Hot Tub - Ste...            58
# 3     Cassiar Cannery ~ where history and nature meet~            56
# 4    2 bedroom suite located between Victoria & Sidney            19
# ..                                                 ...           ...
# 193                                     1226 Flint Ave             0
# 194                     Cute Convenient Cozy and Clean             0
# 195                                 Simone Hospitality             0
# 196           SeaView Getaway - Minutes From The Beach             0
# 197                                  Silver Star Lodge             0
#
#      Average Rating   Latitude   Longitude
# 0               5.0  50.322350 -119.164970
# 1               5.0  49.236020 -122.960540
# ...

# %%
full_data_tp_df.to_csv("full_data_tp_df", index=False)
